# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("/Users/sajanshergill/Machine-Learning-Projects/Trust-Graph")
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from pathlib import Path
import pandas as pd

from src.config import Config
from src.data_loader import load_yelp_minimal

cfg = Config(
    data_dir= Path("/Users/sajanshergill/Machine-Learning-Projects/Trust-Graph/data/yelp"),
    max_reviews= 50_000,
    seed=42,
    burst_window_days=14
)

reviews, users, businesses = load_yelp_minimal(
    data_dir = cgf.data_dir,
    max_review = cfg.max_reviews,
    seed = cfg.seed,
    keep_text = False 
)

reviews.head(), len(reviews)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 from src.config import Config
#       5 from src.data_loader import load_yelp_minimal
# ----> 7 cfg = Config(
#       8     data_dir= Path("/Users/sajanshergill/Machine-Learning-Projects/Trust-Graph/data/yelp"),
#       9     max_reviews= 50_000,
#      10     seed=42,
#      11     burst_window_days=14
#      12 )
#      14 reviews, users, businesses = load_yelp_minimal(
#      15     data_dir = cgf.data_dir,
#      16     max_review = cfg.max_reviews,
#      17     seed = cfg.seed,
#      18     keep_text = False
#      19 )
#      21 reviews.head(), len(reviews)
#
# TypeError: Config.__init__() got an unexpected keyword argument 'burst_window_days'
